# %%
import pandas as pd
from sklearn.cluster import KMeans
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
import pandas as pd
before_attack = pd.read_csv('before_X.csv', header=None, skiprows=1)
after_attack = pd.read_csv('attack_X.csv', header=None, skiprows=1)

# %%
# 读取数据 
X = before_attack.values

# 设置K-means模型，这里设置K=2
kmeans = KMeans(n_clusters=2,random_state=42)
kmeans.fit(X)

# 获取每个数据点的簇分配
labels = kmeans.labels_

# 获取聚类中心
centers = kmeans.cluster_centers_

# 绘制散点图
plt.scatter(X[:, 0], X[:, 1], c=labels, cmap='rainbow')
plt.scatter(centers[:, 0], centers[:, 1], c='black', marker='x')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.title('K-means Clustering')
plt.show()

# %%
# 读取数据
X = after_attack.values

# 设置K-means模型，这里设置K=2
kmeans = KMeans(n_clusters=2,random_state=42)
kmeans.fit(X)

# 获取每个数据点的簇分配
labels = kmeans.labels_

# 获取聚类中心
centers = kmeans.cluster_centers_

# 绘制散点图
plt.scatter(X[:, 0], X[:, 1], c=labels, cmap='rainbow')
plt.scatter(centers[:, 0], centers[:, 1], c='black', marker='x')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.title('K-means Clustering')
plt.show()

# %%
before_attack
# Out:
#             0         1
# 0    0.000000  1.000000
# 1   -4.330264 -4.608254
# 2    3.271140 -4.203657
# 3   -4.511375 -5.051049
# 4    5.039822 -4.461062
# ..        ...       ...
# 296  3.637617 -3.466207
# 297 -3.827324 -3.620597
# 298  2.536199 -3.727303
# 299 -3.177381 -2.691002
# 300  4.477575 -3.717166
#
# [301 rows x 2 columns]

# %%
after_attack
# Out:
#             0         1
# 0    0.000000  1.000000
# 1   -4.330264 -4.608254
# 2    3.271140 -4.203657
# 3   -4.511375 -5.051049
# 4    5.039822 -4.461062
# ..        ...       ...
# 326 -3.556998 -2.715475
# 327  4.205544 -4.890879
# 328  4.367538 -3.374031
# 329 -3.001426 -1.790310
# 330 -5.264369 -5.566905
#
# [331 rows x 2 columns]
